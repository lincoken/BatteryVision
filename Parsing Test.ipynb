# %%
from bs4 import BeautifulSoup
import re, string, unicodedata, nltk, pprint
from nltk import word_tokenize
import contractions
from nltk import word_tokenize, sent_tokenize
nltk.download('punkt')
"""
import inflect
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk.stem import LancasterStemmer, WordNetLemmatizer
"""
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dcm96\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# '\nimport inflect\nfrom bs4 import BeautifulSoup\nfrom nltk.corpus import stopwords\nfrom nltk.stem import LancasterStemmer, WordNetLemmatizer\n'

# %%
def ReadFile(filename="Sample.txt"):
    file = open(filename,mode='r')
    # read all lines at once
    text = file.read()
    file.close()
    return text

# %%
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

def strip_until_start(text):
    if "Abstract" in text:
        text = text.split("Abstract",1)
    return text[1]                 # Assumes that 'Abstract' is only used as a title

def strip_after_references(text):
    if "References" in text:
        index = raw_text.rfind("References")
        return text[:index]
    elif "references" in text:
        index = raw_text.rfind("references")
        return text[:index]

# %% [markdown]
# ## What is a good way to locate the beginning and end of the main text?

# %%
raw_text = ReadFile("Sample.txt")
# print(strip_until_start(raw_text))
"References" in raw_text
# raw_text.rfind("references")
# raw_text[38972-20 : 38972+10]
# print(strip_after_references(raw_text))
# Out:
# False

# %% [markdown]
# ## Now to tokanize the text

# %%
def replace_contractions(text):
    """Replace contractions in string of text"""
    return contractions.fix(text)

def remove_non_ascii(words):
    """Remove non-ASCII characters from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
        new_words.append(new_word)
    return new_words

def to_lowercase(words):
    """Convert all characters to lowercase from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = word.lower()
        new_words.append(new_word)
    return new_words

def remove_punctuation(words):
    """Remove punctuation from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = re.sub(r'[^\w\s]', '', word)
        if new_word != '':
            new_words.append(new_word)
    return new_words

# %%
def clean_text(text):
    text = replace_contractions(text)
    words = word_tokenize(text)
    words = remove_non_ascii(words)
    words = to_lowercase(words)
    words = remove_punctuation(words)
    return words

# %%
clean = clean_text(raw_text)

# %%
clean
# Out:
# ['royal',
#  'society',
#  'of',
#  'chemistry',
#  'view',
#  'pdf',
#  'versionprevious',
#  'articlenext',
#  'article',
#  'doi',
#  '101039c6ta08828g',
#  'communication',
#  'j',
#  'mater',
#  'chem',
#  'a',
#  '2017',
#  '5',
#  '942946',
#  'a',
#  'novel',
#  'device',
#  'structure',
#  'for',
#  'a',
#  'lowcost',
#  'lis',
#  'battery',
#  'zhen',
#  'liu',
#  'orcid',
#  'logoab',
#  'xiang',
#  'zheng',
#  'ab',
#  'ningyi',
#  'yuan',
#  'ab',
#  'and',
#  'jianning',
#  'ding',
#  'ab',
#  'athe',
#  'school',
#  'of',
#  'materials',
#  'science',
#  'and',
#  'engineering',
#  'jiangsu',
#  'collaborative',
#  'innovation',
#  'center',
#  'of',
#  'photovolatic',
#  'science',
#  'and',
#  'engineering',
#  'changzhou',
#  'university',
#  'changzhou',
#  '213164',
#  'jiangsu',
#  'china',
#  'email',
#  'liuzhen',
#  'cczueducn',
#  'dingjn',
#  'cczueducn',
#  'bjiangsu',
#  'province',
#  'cutlivation',
#  'base',
#  'for',
#  'state',
#  'key',
# ...
